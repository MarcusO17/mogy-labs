# %% [markdown]
# # Le-Net5 - MNIST
# ### Imports

# %%
import torch
import torchvision
import numpy as np
import matplotlib.pyplot as plt

# %%
# Local Helpers
from helpers.helper_dataset import get_dataloaders_mnist
from helpers.helper_evaluation import set_all_seeds, set_deterministic
from helpers.helper_train import train_model
from helpers.helper_plotting import plot_training_loss, plot_accuracy, show_examples

# %%
# GLOBALS
RANDOM_SEED = 42
BATCH_SIZE = 256
NUM_EPOCHS = 15
DEVICE = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

# %%
set_all_seeds(RANDOM_SEED)

# %% [markdown]
# ## Loading Dataset

# %%
# Loading MNIST Dataset

resize_transform = torchvision.transforms.Compose(
    [
        torchvision.transforms.Resize((32,32)),
        torchvision.transforms.ToTensor(),
        torchvision.transforms.Normalize((0.5),(0.5))
    ]
)

train_loader, valid_loader, test_loader = get_dataloaders_mnist(
    batch_size=BATCH_SIZE,
    validation_fraction=0.1,
    train_transforms=resize_transform,
    test_transforms=resize_transform
)

# %%
for imgs, labels in train_loader:
    print('Image Batch Dim', imgs.shape)
    print('Image Label dim: ',labels.shape)
    print('Class Label Examples',labels[:10])
    break
# Out:
# Image Batch Dim torch.Size([256, 1, 32, 32])
# Image Label dim:  torch.Size([256])
# Class Label Examples tensor([8, 5, 0, 4, 9, 0, 6, 2, 1, 6])
